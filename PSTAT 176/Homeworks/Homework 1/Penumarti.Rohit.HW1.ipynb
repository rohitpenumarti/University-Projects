# %%
import numpy as np
from itertools import product
import pandas as pd
import math

# %%
# Problem 4
S0 = 10
u = 1.05
d = 0.95
r = 0.01
N = 8
K = 11
q = (1+r-d)/(u-d)

w = np.array(list(product((0.95,1.05), repeat=8)))
SN = S0*np.cumprod(w, axis=1)
SN = np.insert(SN, 0, S0, axis=1)

B = np.array([11, 11.5, 12, 12.5, 13])
payoff = np.zeros((np.size(SN, 0), np.size(B)))
non_zero_count = np.zeros(np.size(B))

numH = (w == 1.05).sum(axis=1)
numT = 8-numH
risk_neutral_prob = np.zeros((np.size(SN, 0), np.size(B)))
risk_neutral_prob_B = np.zeros(np.size(B))
price = np.zeros(np.size(B))

for i in range(np.size(B)):
    for j in range(np.size(SN, 0)):
        if(np.amax(SN[j]) > B[i]):
            risk_neutral_prob[j,i] += q**numH[j]*(1-q)**numT[j]
            if(SN[j,8] > K):
                payoff[j,i] = SN[j,8]-K
                price[i] += risk_neutral_prob[j,i]*payoff[j,i]
                if(payoff[j,i] != 0):
                    non_zero_count[i] += 1
    risk_neutral_prob_B[i] = np.sum(risk_neutral_prob[:,i])
    
price = price/(1+r)**8
results = {'B Value':B, 'Non-zero Count':non_zero_count, 'Risk-Neutral Prob':risk_neutral_prob_B, 'No-Arbitrage Price':price}

df = pd.DataFrame(results)
dfStyler = df.style.set_properties(**{'text-align': 'center'})
dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'center')])])
dfStyler
# Out:
# <style  type="text/css" >
#     #T_9b45bce2_88ff_11ea_8542_98e93f1fff18 th {
#           text-align: center;
#     }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row0_col0 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row0_col1 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row0_col2 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row0_col3 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row1_col0 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row1_col1 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row1_col2 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row1_col3 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row2_col0 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row2_col1 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row2_col2 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row2_col3 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row3_col0 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row3_col1 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row3_col2 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row3_col3 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row4_col0 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row4_col1 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row4_col2 {
#             text-align:  center;
#         }    #T_9b45bce2_88ff_11ea_8542_98e93f1fff18row4_col3 {
#             text-align:  center;
#         }</style><table id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >B Value</th>        <th class="col_heading level0 col1" >Non-zero Count</th>        <th class="col_heading level0 col2" >Risk-Neutral Prob</th>        <th class="col_heading level0 col3" >No-Arbitrage Price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row0_col0" class="data row0 col0" >11</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row0_col1" class="data row0 col1" >37</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row0_col2" class="data row0 col2" >0.550771</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row0_col3" class="data row0 col3" >0.465635</td>
#             </tr>
#             <tr>
#                         <th id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row1_col0" class="data row1 col0" >11.5</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row1_col1" class="data row1 col1" >37</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row1_col2" class="data row1 col2" >0.483494</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row1_col3" class="data row1 col3" >0.465635</td>
#             </tr>
#             <tr>
#                         <th id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row2_col0" class="data row2 col0" >12</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row2_col1" class="data row2 col1" >37</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row2_col2" class="data row2 col2" >0.358525</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row2_col3" class="data row2 col3" >0.465635</td>
#             </tr>
#             <tr>
#                         <th id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row3_col0" class="data row3 col0" >12.5</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row3_col1" class="data row3 col1" >17</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row3_col2" class="data row3 col2" >0.171072</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row3_col3" class="data row3 col3" >0.314749</td>
#             </tr>
#             <tr>
#                         <th id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row4_col0" class="data row4 col0" >13</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row4_col1" class="data row4 col1" >10</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row4_col2" class="data row4 col2" >0.113841</td>
#                         <td id="T_9b45bce2_88ff_11ea_8542_98e93f1fff18row4_col3" class="data row4 col3" >0.261939</td>
#             </tr>
#     </tbody></table>

# %%
# Problem 6 Extra Credit
S0 = 1.05
u = 1.01
d = 0.99
r = 0
q = (1+r-d)/(u-d)

def sim_N_period_binom(N):
    w = np.array(list(product((d,u), repeat=N)))
    SN = S0*np.cumprod(w, axis=1)
    SN = np.insert(SN, 0, S0, axis=1)
    return SN

def hit_box_option_payoff(t, S, N):
    t1 = math.ceil(t[0])
    t2 = int(t[1])
    
    SN = sim_N_period_binom(N)
    SN_box = SN[:, t1:t2+1]
        
    box_check = np.where(np.logical_and(SN_box>=S[0], SN_box<=S[1]), 1, 0)
    payoff = np.any(box_check, axis=1)
    
    price = q**N*np.sum(payoff)/(1+r)**N
    return price

def miss_box_option_payoff(t, S, N):
    t1 = math.ceil(t[0])
    t2 = int(t[1])
    
    SN = sim_N_period_binom(N)
    SN_box = SN[:, t1:t2+1]
    
    box_check = np.where(np.logical_or(SN_box<=S[0], SN_box>=S[1]), 0, 1)
    payoff = 1-np.any(box_check, axis=1)
    
    price = q**N*np.sum(payoff)/(1+r)**N
    return price

print("The price of the Hit Box Option is: " + str(hit_box_option_payoff([1.9, 4.1], [1.03, 1.07], 4)))
print("The price of the Miss Box Option is: " + str(miss_box_option_payoff([1.9, 4.1], [1.045, 1.055], 4)))
# Out:
# The price of the Hit Box Option is: 0.75
# The price of the Miss Box Option is: 0.375
